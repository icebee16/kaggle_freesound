# %% [markdown]
# # Freesound Audio Tagging 2019
#
# ## StratifiedKFold using randomized algolitim
#
# reference : https://www.kaggle.com/osciiart/multilabel-stratifiedkfold-by-randomized-algorithm

# %%
# ============= #
# import module #
# ============= #

# sys
import gc
import os
import warnings

# util
import time
import logging
import datetime
import tqdm
from pathlib import Path
from IPython.display import display
from itertools import chain

# numerical
import numpy as np
import pandas as pd
from scipy import stats

# machine learning
from sklearn.model_selection import KFold, StratifiedKFold

# visualize
import matplotlib.pyplot as plt
import seaborn as sns

# addiction
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load Data

# %%
is_curated = False

# %%
ROOT_PATH = Path(".").absolute().parents[0]

# %%
train_curated_df = pd.read_csv(ROOT_PATH / "input" / "train_curated.csv")
train_curated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4970 entries, 0 to 4969
# Data columns (total 2 columns):
# fname     4970 non-null object
# labels    4970 non-null object
# dtypes: object(2)
# memory usage: 77.7+ KB

# %%
train_noisy_df = pd.read_csv(ROOT_PATH / "input" / "train_noisy.csv")
train_noisy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19815 entries, 0 to 19814
# Data columns (total 2 columns):
# fname     19815 non-null object
# labels    19815 non-null object
# dtypes: object(2)
# memory usage: 309.7+ KB

# %%
test_df = pd.read_csv(ROOT_PATH / "input" / "sample_submission.csv")
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1120 entries, 0 to 1119
# Data columns (total 81 columns):
# fname                                 1120 non-null object
# Accelerating_and_revving_and_vroom    1120 non-null int64
# Accordion                             1120 non-null int64
# Acoustic_guitar                       1120 non-null int64
# Applause                              1120 non-null int64
# Bark                                  1120 non-null int64
# Bass_drum                             1120 non-null int64
# Bass_guitar                           1120 non-null int64
# Bathtub_(filling_or_washing)          1120 non-null int64
# Bicycle_bell                          1120 non-null int64
# Burping_and_eructation                1120 non-null int64
# Bus                                   1120 non-null int64
# Buzz                                  1120 non-null int64
# Car_passing_by                        1120 non-null int64
# Cheering                              1120 non-null int64
# Chewing_and_mastication               1120 non-null int64
# Child_speech_and_kid_speaking         1120 non-null int64
# Chink_and_clink                       1120 non-null int64
# Chirp_and_tweet                       1120 non-null int64
# Church_bell                           1120 non-null int64
# Clapping                              1120 non-null int64
# Computer_keyboard                     1120 non-null int64
# Crackle                               1120 non-null int64
# Cricket                               1120 non-null int64
# Crowd                                 1120 non-null int64
# Cupboard_open_or_close                1120 non-null int64
# Cutlery_and_silverware                1120 non-null int64
# Dishes_and_pots_and_pans              1120 non-null int64
# Drawer_open_or_close                  1120 non-null int64
# Drip                                  1120 non-null int64
# Electric_guitar                       1120 non-null int64
# Fart                                  1120 non-null int64
# Female_singing                        1120 non-null int64
# Female_speech_and_woman_speaking      1120 non-null int64
# Fill_(with_liquid)                    1120 non-null int64
# Finger_snapping                       1120 non-null int64
# Frying_(food)                         1120 non-null int64
# Gasp                                  1120 non-null int64
# Glockenspiel                          1120 non-null int64
# Gong                                  1120 non-null int64
# Gurgling                              1120 non-null int64
# Harmonica                             1120 non-null int64
# Hi-hat                                1120 non-null int64
# Hiss                                  1120 non-null int64
# Keys_jangling                         1120 non-null int64
# Knock                                 1120 non-null int64
# Male_singing                          1120 non-null int64
# Male_speech_and_man_speaking          1120 non-null int64
# Marimba_and_xylophone                 1120 non-null int64
# Mechanical_fan                        1120 non-null int64
# Meow                                  1120 non-null int64
# Microwave_oven                        1120 non-null int64
# Motorcycle                            1120 non-null int64
# Printer                               1120 non-null int64
# Purr                                  1120 non-null int64
# Race_car_and_auto_racing              1120 non-null int64
# Raindrop                              1120 non-null int64
# Run                                   1120 non-null int64
# Scissors                              1120 non-null int64
# Screaming                             1120 non-null int64
# Shatter                               1120 non-null int64
# Sigh                                  1120 non-null int64
# Sink_(filling_or_washing)             1120 non-null int64
# Skateboard                            1120 non-null int64
# Slam                                  1120 non-null int64
# Sneeze                                1120 non-null int64
# Squeak                                1120 non-null int64
# Stream                                1120 non-null int64
# Strum                                 1120 non-null int64
# Tap                                   1120 non-null int64
# Tick-tock                             1120 non-null int64
# Toilet_flush                          1120 non-null int64
# Traffic_noise_and_roadway_noise       1120 non-null int64
# Trickle_and_dribble                   1120 non-null int64
# Walk_and_footsteps                    1120 non-null int64
# Water_tap_and_faucet                  1120 non-null int64
# Waves_and_surf                        1120 non-null int64
# Whispering                            1120 non-null int64
# Writing                               1120 non-null int64
# Yell                                  1120 non-null int64
# Zipper_(clothing)                     1120 non-null int64
# dtypes: int64(80), object(1)
# memory usage: 708.8+ KB

# %% [markdown]
# ## Split Fold

# %% [markdown]
# ### Set parameters

# %%
NUM_FOLD = 5
SEED = 1116
LABELS = test_df.columns[1:].tolist()
NUM_CLASS = len(LABELS)

# %%
np.random.seed(SEED)

# %% [markdown]
# ### Split Curated Train

# %%
train_df = train_curated_df if is_curated else train_noisy_df

# %%
for label in LABELS:
    train_df[label] = train_df['labels'].apply(lambda x: label in x)
display(train_df.shape)
train_df.head(10)
# Out:
# (19815, 82)
#           fname                                          labels  \
# 0  00097e21.wav                    Bathtub_(filling_or_washing)
# 1  000b6cfb.wav                                      Motorcycle
# 2  00116cd2.wav              Marimba_and_xylophone,Glockenspiel
# 3  00127d14.wav  Water_tap_and_faucet,Sink_(filling_or_washing)
# 4  0019adae.wav                                        Raindrop
# 5  001b819d.wav                                     Bass_guitar
# 6  001c054e.wav                    Raindrop,Trickle_and_dribble
# 7  001ceaf1.wav                           Strum,Acoustic_guitar
# 8  001f3501.wav                                Bass_drum,Hi-hat
# 9  0020becb.wav                                       Harmonica
#
#    Accelerating_and_revving_and_vroom  Accordion  Acoustic_guitar  Applause  \
# 0                               False      False            False     False
# 1                               False      False            False     False
# 2                               False      False            False     False
# 3                               False      False            False     False
# 4                               False      False            False     False
# 5                               False      False            False     False
# 6                               False      False            False     False
# 7                               False      False             True     False
# 8                               False      False            False     False
# 9                               False      False            False     False
#
#     Bark  Bass_drum  Bass_guitar  Bathtub_(filling_or_washing)  \
# 0  False      False        False                          True
# 1  False      False        False                         False
# 2  False      False        False                         False
# 3  False      False        False                         False
# 4  False      False        False                         False
# 5  False      False         True                         False
# 6  False      False        False                         False
# 7  False      False        False                         False
# 8  False       True        False                         False
# 9  False      False        False                         False
#
#          ...          Toilet_flush  Traffic_noise_and_roadway_noise  \
# 0        ...                 False                            False
# 1        ...                 False                            False
# 2        ...                 False                            False
# 3        ...                 False                            False
# 4        ...                 False                            False
# 5        ...                 False                            False
# 6        ...                 False                            False
# 7        ...                 False                            False
# 8        ...                 False                            False
# 9        ...                 False                            False
#
#    Trickle_and_dribble  Walk_and_footsteps  Water_tap_and_faucet  \
# 0                False               False                 False
# 1                False               False                 False
# 2                False               False                 False
# 3                False               False                  True
# 4                False               False                 False
# 5                False               False                 False
# 6                 True               False                 False
# 7                False               False                 False
# 8                False               False                 False
# 9                False               False                 False
#
#    Waves_and_surf  Whispering  Writing   Yell  Zipper_(clothing)
# 0           False       False    False  False              False
# 1           False       False    False  False              False
# 2           False       False    False  False              False
# 3           False       False    False  False              False
# 4           False       False    False  False              False
# 5           False       False    False  False              False
# 6           False       False    False  False              False
# 7           False       False    False  False              False
# 8           False       False    False  False              False
# 9           False       False    False  False              False
#
# [10 rows x 82 columns]

# %% [markdown]
# ### Stratified KFold

# %% [markdown]
# #### KFold
#
# ・No Use

# %%
# try KFold
folds = list(KFold(n_splits=NUM_FOLD, shuffle=True, random_state=SEED).split(np.arange(len(train_df))))
train_df['fold'] = 0
for i in range(NUM_FOLD):
    train_df['fold'][folds[i][1]] = i
display(train_df.head(5))
# Out:
#           fname                                          labels  \
# 0  00097e21.wav                    Bathtub_(filling_or_washing)
# 1  000b6cfb.wav                                      Motorcycle
# 2  00116cd2.wav              Marimba_and_xylophone,Glockenspiel
# 3  00127d14.wav  Water_tap_and_faucet,Sink_(filling_or_washing)
# 4  0019adae.wav                                        Raindrop
#
#    Accelerating_and_revving_and_vroom  Accordion  Acoustic_guitar  Applause  \
# 0                               False      False            False     False
# 1                               False      False            False     False
# 2                               False      False            False     False
# 3                               False      False            False     False
# 4                               False      False            False     False
#
#     Bark  Bass_drum  Bass_guitar  Bathtub_(filling_or_washing)  ...   \
# 0  False      False        False                          True  ...
# 1  False      False        False                         False  ...
# 2  False      False        False                         False  ...
# 3  False      False        False                         False  ...
# 4  False      False        False                         False  ...
#
#    Traffic_noise_and_roadway_noise  Trickle_and_dribble  Walk_and_footsteps  \
# 0                            False                False               False
# 1                            False                False               False
# 2                            False                False               False
# 3                            False                False               False
# 4                            False                False               False
#
#    Water_tap_and_faucet  Waves_and_surf  Whispering  Writing   Yell  \
# 0                 False           False       False    False  False
# 1                 False           False       False    False  False
# 2                 False           False       False    False  False
# 3                  True           False       False    False  False
# 4                 False           False       False    False  False
#
#    Zipper_(clothing)  fold
# 0              False     0
# 1              False     0
# 2              False     4
# 3              False     4
# 4              False     4
#
# [5 rows x 83 columns]

# %%
# Check how well the folds are stratified.
def check_fold(df):
    print("fold                                         1    2    3    4    5   total")
    print("==========================================================================")
    for label in LABELS:
        label_padded = label + " "*(40-len(label))
        dist = ": "
        for i in range(NUM_FOLD):
            dist += "{:4d} ".format(df[label][folds[i][1]].sum())
        dist += "{:4d} ".format(df[label].sum())
        print(label_padded + dist)
    label_padded = "total" + " "*(40-len("total"))
    dist = ": "
    for i in range(NUM_FOLD):
        dist += "{:4d} ".format(df[df['fold']==i].shape[0])
    dist += "{:4d} ".format(df.shape[0])
    print(label_padded + dist)

check_fold(train_df)
# Out:
# fold                                         1    2    3    4    5   total
# ==========================================================================
# Accelerating_and_revving_and_vroom      :   67   63   64   51   55  300
# Accordion                               :   57   60   68   60   55  300
# Acoustic_guitar                         :   67   66   40   60   67  300
# Applause                                :   61   56   48   58   77  300
# Bark                                    :   71   55   60   55   59  300
# Bass_drum                               :   58   54   70   62   56  300
# Bass_guitar                             :   48   71   65   57   59  300
# Bathtub_(filling_or_washing)            :   54   68   52   60   66  300
# Bicycle_bell                            :   59   65   53   72   51  300
# Burping_and_eructation                  :   54   57   66   65   58  300
# Bus                                     :   53   59   61   59   68  300
# Buzz                                    :   52   54   71   64   59  300
# Car_passing_by                          :   65   56   63   62   54  300
# Cheering                                :   62   52   58   75   53  300
# Chewing_and_mastication                 :   70   55   62   57   56  300
# Child_speech_and_kid_speaking           :   66   52   61   51   70  300
# Chink_and_clink                         :   65   61   63   65   46  300
# Chirp_and_tweet                         :   68   67   55   55   55  300
# Church_bell                             :   60   62   68   54   56  300
# Clapping                                :   53   62   62   50   73  300
# Computer_keyboard                       :   67   61   48   60   64  300
# Crackle                                 :   62   62   65   50   61  300
# Cricket                                 :   49   64   57   73   57  300
# Crowd                                   :   58   56   56   69   61  300
# Cupboard_open_or_close                  :   51   66   57   51   75  300
# Cutlery_and_silverware                  :   58   63   63   55   61  300
# Dishes_and_pots_and_pans                :   61   65   57   48   69  300
# Drawer_open_or_close                    :   57   68   64   53   58  300
# Drip                                    :   63   58   61   65   53  300
# Electric_guitar                         :   51   56   62   64   67  300
# Fart                                    :   57   53   66   63   61  300
# Female_singing                          :   59   50   70   53   68  300
# Female_speech_and_woman_speaking        :   55   65   53   54   73  300
# Fill_(with_liquid)                      :   57   70   59   56   58  300
# Finger_snapping                         :   69   60   59   50   62  300
# Frying_(food)                           :   58   72   56   53   61  300
# Gasp                                    :   62   55   57   56   70  300
# Glockenspiel                            :   67   62   45   74   52  300
# Gong                                    :   55   63   69   61   52  300
# Gurgling                                :   63   61   62   60   54  300
# Harmonica                               :   62   65   53   59   61  300
# Hi-hat                                  :   61   50   62   62   65  300
# Hiss                                    :   51   62   53   71   63  300
# Keys_jangling                           :   65   63   58   64   50  300
# Knock                                   :   60   54   69   53   64  300
# Male_singing                            :   67   55   60   67   51  300
# Male_speech_and_man_speaking            :   67   64   52   52   65  300
# Marimba_and_xylophone                   :   66   61   51   64   58  300
# Mechanical_fan                          :   68   64   61   60   47  300
# Meow                                    :   62   54   64   66   54  300
# Microwave_oven                          :   62   61   44   58   75  300
# Motorcycle                              :   62   58   71   49   60  300
# Printer                                 :   55   53   57   66   69  300
# Purr                                    :   63   65   54   65   53  300
# Race_car_and_auto_racing                :   78   64   49   55   54  300
# Raindrop                                :   55   62   60   56   67  300
# Run                                     :   57   54   57   65   67  300
# Scissors                                :   76   61   46   57   60  300
# Screaming                               :   59   54   44   81   62  300
# Shatter                                 :   62   52   70   63   53  300
# Sigh                                    :   57   57   56   66   64  300
# Sink_(filling_or_washing)               :   62   67   54   63   54  300
# Skateboard                              :   59   56   53   67   65  300
# Slam                                    :   64   54   64   58   60  300
# Sneeze                                  :   56   55   72   58   59  300
# Squeak                                  :   58   58   62   59   63  300
# Stream                                  :   66   62   55   61   56  300
# Strum                                   :   56   55   50   63   76  300
# Tap                                     :   61   57   76   58   48  300
# Tick-tock                               :   64   61   62   60   53  300
# Toilet_flush                            :   60   62   54   60   64  300
# Traffic_noise_and_roadway_noise         :   43   58   76   69   54  300
# Trickle_and_dribble                     :   64   64   60   61   51  300
# Walk_and_footsteps                      :   58   61   60   63   58  300
# Water_tap_and_faucet                    :   64   65   61   62   48  300
# Waves_and_surf                          :   73   53   53   65   56  300
# Whispering                              :   55   64   66   62   53  300
# Writing                                 :   58   65   62   55   60  300
# Yell                                    :   54   62   80   57   47  300
# Zipper_(clothing)                       :   59   67   52   58   64  300
# total                                   : 3963 3963 3963 3963 3963 19815

# %% [markdown]
# #### Only Single KFold

# %%
# calculate number of positive label for each sample
train_df['num_labels'] = train_df[LABELS].values.sum(axis=1)
train_df.loc[:,['labels', 'num_labels']].head(5)
# Out:
#                                            labels  num_labels
# 0                    Bathtub_(filling_or_washing)           1
# 1                                      Motorcycle           1
# 2              Marimba_and_xylophone,Glockenspiel           2
# 3  Water_tap_and_faucet,Sink_(filling_or_washing)           2
# 4                                        Raindrop           1

# %%
# extract data sample with single label and do StratifiedKFold
train_single_df = train_df[train_df['num_labels']==1].reset_index(drop=True)
single_folds = list(StratifiedKFold(n_splits=NUM_FOLD, shuffle=True, random_state=SEED).split(
    np.arange(len(train_single_df)), train_single_df[LABELS].values.argmax(axis=1)))
train_single_df['fold'] = 0
for i in range(NUM_FOLD):
    train_single_df['fold'][single_folds[i][1]] = i
check_fold(train_single_df)
# Out:
# fold                                         1    2    3    4    5   total
# ==========================================================================
# Accelerating_and_revving_and_vroom      :   51   62   41   49   47  250
# Accordion                               :   49   43   58   59   52  261
# Acoustic_guitar                         :   51   45   52   47   54  249
# Applause                                :   47   59   47   48   53  254
# Bark                                    :   51   50   51   50   55  257
# Bass_drum                               :   37   50   44   39   30  200
# Bass_guitar                             :   42   56   46   47   44  235
# Bathtub_(filling_or_washing)            :   55   38   38   41   37  209
# Bicycle_bell                            :   41   47   46   48   39  221
# Burping_and_eructation                  :   42   44   47   47   41  221
# Bus                                     :   53   65   38   53   60  269
# Buzz                                    :   55   40   44   39   41  219
# Car_passing_by                          :   33   44   43   41   48  209
# Cheering                                :   45   48   49   38   65  245
# Chewing_and_mastication                 :   32   28   24   32   35  151
# Child_speech_and_kid_speaking           :   63   44   56   46   42  251
# Chink_and_clink                         :   38   36   45   38   43  200
# Chirp_and_tweet                         :   40   60   53   61   49  263
# Church_bell                             :   47   70   40   58   44  259
# Clapping                                :   53   42   46   55   52  248
# Computer_keyboard                       :   36   42   42   30   45  195
# Crackle                                 :   48   45   46   42   50  231
# Cricket                                 :   46   57   57   52   47  259
# Crowd                                   :   55   40   50   55   46  246
# Cupboard_open_or_close                  :   26   22   28   32   33  141
# Cutlery_and_silverware                  :    7    5    8    7   14   41
# Dishes_and_pots_and_pans                :   13   10   11    7    9   50
# Drawer_open_or_close                    :   38   40   30   47   34  189
# Drip                                    :   22   19   15   13   16   85
# Electric_guitar                         :   19   20   29   19   31  118
# Fart                                    :   34   36   33   37   32  172
# Female_singing                          :   51   53   48   51   48  251
# Female_speech_and_woman_speaking        :   49   61   52   62   42  266
# Fill_(with_liquid)                      :   20   14   23   14   21   92
# Finger_snapping                         :   41   29   28   36   39  173
# Frying_(food)                           :   48   44   49   41   47  229
# Gasp                                    :   22   25   35   21   18  121
# Glockenspiel                            :   19   20   21   15   13   88
# Gong                                    :   50   42   43   49   54  238
# Gurgling                                :   41   51   39   49   45  225
# Harmonica                               :   45   40   52   52   45  234
# Hi-hat                                  :   21   41   30   43   41  176
# Hiss                                    :   51   50   43   53   51  248
# Keys_jangling                           :   47   44   43   37   40  211
# Knock                                   :   29   45   28   41   41  184
# Male_singing                            :   55   41   46   48   58  248
# Male_speech_and_man_speaking            :   54   50   46   58   55  263
# Marimba_and_xylophone                   :   15   27   13   17   26   98
# Mechanical_fan                          :   58   58   50   64   42  272
# Meow                                    :   55   60   43   39   58  255
# Microwave_oven                          :   51   40   53   36   44  224
# Motorcycle                              :   58   60   51   47   50  266
# Printer                                 :   45   64   57   49   54  269
# Purr                                    :   45   56   51   39   34  225
# Race_car_and_auto_racing                :   52   41   58   50   38  239
# Raindrop                                :   41   40   61   56   58  256
# Run                                     :   65   56   53   53   50  277
# Scissors                                :   37   30   34   21   22  144
# Screaming                               :   48   49   59   49   46  251
# Shatter                                 :   38   43   36   41   43  201
# Sigh                                    :   33   38   26   30   40  167
# Sink_(filling_or_washing)               :    8    5    9   13    6   41
# Skateboard                              :   43   54   58   62   47  264
# Slam                                    :   51   47   48   51   49  246
# Sneeze                                  :   29   37   35   28   46  175
# Squeak                                  :   56   33   41   53   34  217
# Stream                                  :   51   48   49   67   50  265
# Strum                                   :   26   14   15   25   20  100
# Tap                                     :   43   51   43   66   45  248
# Tick-tock                               :   43   53   54   54   45  249
# Toilet_flush                            :   32   21   32   22   28  135
# Traffic_noise_and_roadway_noise         :   48   63   51   54   59  275
# Trickle_and_dribble                     :   53   50   41   42   38  224
# Walk_and_footsteps                      :   51   44   53   47   63  258
# Water_tap_and_faucet                    :    9    5    3    7    4   28
# Waves_and_surf                          :   53   45   61   67   65  291
# Whispering                              :   37   35   45   43   32  192
# Writing                                 :   38   31   31   33   42  175
# Yell                                    :   60   48   61   45   58  272
# Zipper_(clothing)                       :   21   25   33   20   23  122
# total                                   : 3345 3324 3314 3301 3282 16566

# %%
# extract data sample with multi labels
train_multi_df = train_df[train_df['num_labels']!=1].reset_index(drop=True)

# count each label
label_counts = []
for i in range(NUM_CLASS):    
    label = LABELS[i] + " "*(40-len(LABELS[i]))
    label_counts.append(train_multi_df[LABELS[i]].sum())
    print("{:2d} {} {}".format(i, label, label_counts[i]))
# Out:
#  0 Accelerating_and_revving_and_vroom       50
#  1 Accordion                                39
#  2 Acoustic_guitar                          51
#  3 Applause                                 46
#  4 Bark                                     43
#  5 Bass_drum                                100
#  6 Bass_guitar                              65
#  7 Bathtub_(filling_or_washing)             91
#  8 Bicycle_bell                             79
#  9 Burping_and_eructation                   79
# 10 Bus                                      31
# 11 Buzz                                     81
# 12 Car_passing_by                           91
# 13 Cheering                                 55
# 14 Chewing_and_mastication                  149
# 15 Child_speech_and_kid_speaking            49
# 16 Chink_and_clink                          100
# 17 Chirp_and_tweet                          37
# 18 Church_bell                              41
# 19 Clapping                                 52
# 20 Computer_keyboard                        105
# 21 Crackle                                  69
# 22 Cricket                                  41
# 23 Crowd                                    54
# 24 Cupboard_open_or_close                   159
# 25 Cutlery_and_silverware                   259
# 26 Dishes_and_pots_and_pans                 250
# 27 Drawer_open_or_close                     111
# 28 Drip                                     215
# 29 Electric_guitar                          182
# 30 Fart                                     128
# 31 Female_singing                           49
# 32 Female_speech_and_woman_speaking         34
# 33 Fill_(with_liquid)                       208
# 34 Finger_snapping                          127
# 35 Frying_(food)                            71
# 36 Gasp                                     179
# 37 Glockenspiel                             212
# 38 Gong                                     62
# 39 Gurgling                                 75
# 40 Harmonica                                66
# 41 Hi-hat                                   124
# 42 Hiss                                     52
# 43 Keys_jangling                            89
# 44 Knock                                    116
# 45 Male_singing                             52
# 46 Male_speech_and_man_speaking             37
# 47 Marimba_and_xylophone                    202
# 48 Mechanical_fan                           28
# 49 Meow                                     45
# 50 Microwave_oven                           76
# 51 Motorcycle                               34
# 52 Printer                                  31
# 53 Purr                                     75
# 54 Race_car_and_auto_racing                 61
# 55 Raindrop                                 44
# 56 Run                                      23
# 57 Scissors                                 156
# 58 Screaming                                49
# 59 Shatter                                  99
# 60 Sigh                                     133
# 61 Sink_(filling_or_washing)                259
# 62 Skateboard                               36
# 63 Slam                                     54
# 64 Sneeze                                   125
# 65 Squeak                                   83
# 66 Stream                                   35
# 67 Strum                                    200
# 68 Tap                                      52
# 69 Tick-tock                                51
# 70 Toilet_flush                             165
# 71 Traffic_noise_and_roadway_noise          25
# 72 Trickle_and_dribble                      76
# 73 Walk_and_footsteps                       42
# 74 Water_tap_and_faucet                     272
# 75 Waves_and_surf                           9
# 76 Whispering                               108
# 77 Writing                                  125
# 78 Yell                                     28
# 79 Zipper_(clothing)                        178

# %%
# concatenate single-label data and multi-label data
train_all_df = pd.concat([train_single_df, train_multi_df]).reset_index(drop=True)
check_fold(train_all_df)
# Out:
# fold                                         1    2    3    4    5   total
# ==========================================================================
# Accelerating_and_revving_and_vroom      :   63   74   50   57   56  300
# Accordion                               :   55   52   64   66   63  300
# Acoustic_guitar                         :   61   58   63   51   67  300
# Applause                                :   58   67   59   57   59  300
# Bark                                    :   65   57   60   52   66  300
# Bass_drum                               :   59   73   63   57   48  300
# Bass_guitar                             :   57   66   56   56   65  300
# Bathtub_(filling_or_washing)            :   76   51   63   58   52  300
# Bicycle_bell                            :   50   69   63   66   52  300
# Burping_and_eructation                  :   59   58   65   57   61  300
# Bus                                     :   61   70   42   59   68  300
# Buzz                                    :   71   53   59   56   61  300
# Car_passing_by                          :   53   63   59   58   67  300
# Cheering                                :   53   54   64   54   75  300
# Chewing_and_mastication                 :   65   51   54   68   62  300
# Child_speech_and_kid_speaking           :   75   49   70   55   51  300
# Chink_and_clink                         :   59   57   70   53   61  300
# Chirp_and_tweet                         :   51   73   57   68   51  300
# Church_bell                             :   57   80   46   66   51  300
# Clapping                                :   65   56   54   64   61  300
# Computer_keyboard                       :   54   69   65   50   62  300
# Crackle                                 :   63   56   62   55   64  300
# Cricket                                 :   55   63   66   58   58  300
# Crowd                                   :   64   49   66   67   54  300
# Cupboard_open_or_close                  :   60   51   59   68   62  300
# Cutlery_and_silverware                  :   55   54   70   53   68  300
# Dishes_and_pots_and_pans                :   62   53   72   53   60  300
# Drawer_open_or_close                    :   60   59   56   71   54  300
# Drip                                    :   62   65   60   60   53  300
# Electric_guitar                         :   63   48   61   63   65  300
# Fart                                    :   52   63   61   66   58  300
# Female_singing                          :   60   65   57   59   59  300
# Female_speech_and_woman_speaking        :   56   69   57   70   48  300
# Fill_(with_liquid)                      :   63   49   65   55   68  300
# Finger_snapping                         :   81   53   47   62   57  300
# Frying_(food)                           :   69   58   65   48   60  300
# Gasp                                    :   57   58   74   51   60  300
# Glockenspiel                            :   54   64   67   56   59  300
# Gong                                    :   65   54   50   61   70  300
# Gurgling                                :   51   68   62   61   58  300
# Harmonica                               :   59   51   63   65   62  300
# Hi-hat                                  :   43   72   56   68   61  300
# Hiss                                    :   58   61   53   63   65  300
# Keys_jangling                           :   64   66   60   58   52  300
# Knock                                   :   51   71   46   64   68  300
# Male_singing                            :   69   56   54   55   66  300
# Male_speech_and_man_speaking            :   62   56   51   67   64  300
# Marimba_and_xylophone                   :   48   68   54   57   73  300
# Mechanical_fan                          :   63   66   58   68   45  300
# Meow                                    :   65   68   54   45   68  300
# Microwave_oven                          :   67   55   62   52   64  300
# Motorcycle                              :   68   65   62   49   56  300
# Printer                                 :   50   67   62   55   66  300
# Purr                                    :   60   72   65   52   51  300
# Race_car_and_auto_racing                :   63   53   73   65   46  300
# Raindrop                                :   42   47   77   62   72  300
# Run                                     :   69   63   58   56   54  300
# Scissors                                :   87   58   67   45   43  300
# Screaming                               :   65   55   71   58   51  300
# Shatter                                 :   62   59   54   67   58  300
# Sigh                                    :   59   61   58   57   65  300
# Sink_(filling_or_washing)               :   55   59   63   59   64  300
# Skateboard                              :   48   57   66   76   53  300
# Slam                                    :   61   57   57   66   59  300
# Sneeze                                  :   52   55   63   55   75  300
# Squeak                                  :   76   48   60   70   46  300
# Stream                                  :   57   59   56   70   58  300
# Strum                                   :   75   43   55   69   58  300
# Tap                                     :   58   63   52   71   56  300
# Tick-tock                               :   52   66   67   60   55  300
# Toilet_flush                            :   64   54   65   53   64  300
# Traffic_noise_and_roadway_noise         :   54   72   55   58   61  300
# Trickle_and_dribble                     :   67   65   52   54   62  300
# Walk_and_footsteps                      :   60   54   56   58   72  300
# Water_tap_and_faucet                    :   62   59   61   52   66  300
# Waves_and_surf                          :   55   45   63   71   66  300
# Whispering                              :   56   55   71   64   54  300
# Writing                                 :   71   56   59   48   66  300
# Yell                                    :   64   54   63   54   65  300
# Zipper_(clothing)                       :   47   65   70   55   63  300
# total                                   : 4023 3973 3927 3961 3931 19815

# %% [markdown]
# #### Optimize

# %%
def calc_score(df):
    score = np.zeros([5,NUM_CLASS+1])
    for i in range(5):
        score[i] = df.loc[df.fold==i, LABELS+['num_labels']].values.sum(axis=0)
    score = score.std(axis=0).mean()
    return score
score = calc_score(train_df)
print("KFold score: {:.6f}".format(calc_score(train_df)))
print("StratifiedKFold score: {:.6f}".format(calc_score(train_all_df)))
# Out:
# KFold score: 6.546316
# StratifiedKFold score: 3.964405

# %%
def do_optimize(df, size, steps):
    """
    df: dataframe to optimize folds
    size: number of data to change fold
    steps: number of for loop
    """
    starttime = time.time()
    score = calc_score(df)
    for i in range(steps):
        # select index to change fold
        change_idx = np.random.choice(np.arange(df.shape[0]), size, replace=False)
        # change fold randomly
        change_fold = np.random.randint(0, NUM_FOLD, size)
        df_new = df.copy()
        df_new['fold'][change_idx] = change_fold

        score_new = calc_score(df_new)
        if score_new < score: # if score getting small, folds will be update
            score = score_new
            df = df_new
        if i%500==0:
            print("step: {:4d}, change size: {:2d}, score: {:.6f}, sec: {:.1f}".format(
                i, size, score, time.time()-starttime))
    return df

# %%
# Let's do optimization with randomized algorithm.
train_opt_df = train_all_df.copy()
train_opt_df = do_optimize(train_opt_df, size=64, steps=2000)
train_opt_df = do_optimize(train_opt_df, size=32, steps=2000)
train_opt_df = do_optimize(train_opt_df, size=16, steps=2000)
train_opt_df = do_optimize(train_opt_df, size=8, steps=2000)
train_opt_df = do_optimize(train_opt_df, size=4, steps=2000)
train_opt_df = do_optimize(train_opt_df, size=2, steps=2000)
train_opt_df = do_optimize(train_opt_df, size=1, steps=20000)

print("StratifiedKFold with randomized algorithm score: {:.6f}".format(calc_score(train_opt_df)))
# Out:
# step:    0, change size: 64, score: 3.964405, sec: 0.1
# step:  500, change size: 64, score: 3.014818, sec: 38.9
# step: 1000, change size: 64, score: 2.759164, sec: 74.2
# step: 1500, change size: 64, score: 2.746977, sec: 108.7
# step:    0, change size: 32, score: 2.696284, sec: 0.1
# step:  500, change size: 32, score: 2.478926, sec: 33.5
# step: 1000, change size: 32, score: 2.398053, sec: 72.0
# step: 1500, change size: 32, score: 2.251907, sec: 108.0
# step:    0, change size: 16, score: 2.148352, sec: 0.1
# step:  500, change size: 16, score: 2.068905, sec: 29.7
# step: 1000, change size: 16, score: 1.987804, sec: 59.5
# step: 1500, change size: 16, score: 1.908925, sec: 89.4
# step:    0, change size:  8, score: 1.795690, sec: 0.1
# step:  500, change size:  8, score: 1.590419, sec: 34.8
# step: 1000, change size:  8, score: 1.426721, sec: 73.2
# step: 1500, change size:  8, score: 1.347338, sec: 109.1
# step:    0, change size:  4, score: 1.266438, sec: 0.1
# step:  500, change size:  4, score: 1.158996, sec: 41.1
# step: 1000, change size:  4, score: 1.122631, sec: 80.4
# step: 1500, change size:  4, score: 1.028875, sec: 121.0
# step:    0, change size:  2, score: 0.967081, sec: 0.1
# step:  500, change size:  2, score: 0.962507, sec: 41.1
# step: 1000, change size:  2, score: 0.955873, sec: 82.1
# step: 1500, change size:  2, score: 0.918349, sec: 123.0
# step:    0, change size:  1, score: 0.865720, sec: 0.1
# step:  500, change size:  1, score: 0.847445, sec: 41.1
# step: 1000, change size:  1, score: 0.847445, sec: 82.1
# step: 1500, change size:  1, score: 0.847445, sec: 122.9
# step: 2000, change size:  1, score: 0.847445, sec: 164.0
# step: 2500, change size:  1, score: 0.847445, sec: 205.0
# step: 3000, change size:  1, score: 0.847445, sec: 245.9
# step: 3500, change size:  1, score: 0.847445, sec: 286.8
# step: 4000, change size:  1, score: 0.847445, sec: 327.8
# step: 4500, change size:  1, score: 0.847445, sec: 368.6
# step: 5000, change size:  1, score: 0.847445, sec: 409.5
# step: 5500, change size:  1, score: 0.847445, sec: 450.4
# step: 6000, change size:  1, score: 0.847445, sec: 491.3
# step: 6500, change size:  1, score: 0.847445, sec: 532.2
# step: 7000, change size:  1, score: 0.847445, sec: 573.1
# step: 7500, change size:  1, score: 0.847445, sec: 614.1
# step: 8000, change size:  1, score: 0.847445, sec: 655.0
# step: 8500, change size:  1, score: 0.847445, sec: 696.0
# step: 9000, change size:  1, score: 0.847445, sec: 736.9
# step: 9500, change size:  1, score: 0.847445, sec: 777.8
# step: 10000, change size:  1, score: 0.847445, sec: 818.8
# step: 10500, change size:  1, score: 0.847445, sec: 859.7
# step: 11000, change size:  1, score: 0.847445, sec: 901.3
# step: 11500, change size:  1, score: 0.847445, sec: 943.3
# step: 12000, change size:  1, score: 0.847445, sec: 985.3
# step: 12500, change size:  1, score: 0.847445, sec: 1026.5
# step: 13000, change size:  1, score: 0.847445, sec: 1067.5
# step: 13500, change size:  1, score: 0.847445, sec: 1108.4
# step: 14000, change size:  1, score: 0.847445, sec: 1149.3
# step: 14500, change size:  1, score: 0.847445, sec: 1190.2
# step: 15000, change size:  1, score: 0.847445, sec: 1231.2
# step: 15500, change size:  1, score: 0.847445, sec: 1272.0
# step: 16000, change size:  1, score: 0.847445, sec: 1313.0
# step: 16500, change size:  1, score: 0.847445, sec: 1353.9
# step: 17000, change size:  1, score: 0.847445, sec: 1394.8
# step: 17500, change size:  1, score: 0.847445, sec: 1435.6
# step: 18000, change size:  1, score: 0.847445, sec: 1476.6
# step: 18500, change size:  1, score: 0.847445, sec: 1517.5
# step: 19000, change size:  1, score: 0.847445, sec: 1558.5
# step: 19500, change size:  1, score: 0.847445, sec: 1600.0
# StratifiedKFold with randomized algorithm score: 0.847445

# %%
# Check how well the folds are stratified.
print("fold                                         1    2    3    4    5   total")
print("==========================================================================")
for label in LABELS:
    label_padded = label + " "*(40-len(label))
    dist = ": "
    for i in range(NUM_FOLD):
        dist += "{:4d} ".format(train_all_df[label][train_all_df['fold']==i].sum())
    dist += "{:4d} ".format(train_all_df[label].sum())
    print(label_padded + dist)
label_padded = "total" + " "*(40-len("total"))
dist = ": "
for i in range(5):
    dist += "{:4d} ".format(train_all_df[train_all_df['fold']==i].shape[0])
dist += "{:4d} ".format(train_all_df.shape[0])
print(label_padded + dist)
# Out:
# fold                                         1    2    3    4    5   total
# ==========================================================================
# Accelerating_and_revving_and_vroom      :   64   66   59   56   55  300
# Accordion                               :   60   57   59   63   61  300
# Acoustic_guitar                         :   62   59   55   64   60  300
# Applause                                :   59   61   56   57   67  300
# Bark                                    :   62   61   60   60   57  300
# Bass_drum                               :   53   60   65   65   57  300
# Bass_guitar                             :   61   61   57   61   60  300
# Bathtub_(filling_or_washing)            :   63   58   54   64   61  300
# Bicycle_bell                            :   63   62   59   61   55  300
# Burping_and_eructation                  :   60   59   60   62   59  300
# Bus                                     :   57   60   62   58   63  300
# Buzz                                    :   57   58   66   63   56  300
# Car_passing_by                          :   73   62   54   57   54  300
# Cheering                                :   58   61   60   62   59  300
# Chewing_and_mastication                 :   66   52   56   65   61  300
# Child_speech_and_kid_speaking           :   62   60   56   58   64  300
# Chink_and_clink                         :   63   57   63   65   52  300
# Chirp_and_tweet                         :   59   62   59   57   63  300
# Church_bell                             :   62   60   63   59   56  300
# Clapping                                :   58   58   64   58   62  300
# Computer_keyboard                       :   70   57   52   58   63  300
# Crackle                                 :   61   58   60   59   62  300
# Cricket                                 :   57   61   62   64   56  300
# Crowd                                   :   60   61   59   62   58  300
# Cupboard_open_or_close                  :   60   66   56   53   65  300
# Cutlery_and_silverware                  :   61   63   63   54   59  300
# Dishes_and_pots_and_pans                :   64   61   62   53   60  300
# Drawer_open_or_close                    :   59   66   53   60   62  300
# Drip                                    :   61   59   62   63   55  300
# Electric_guitar                         :   59   60   55   59   67  300
# Fart                                    :   63   57   63   58   59  300
# Female_singing                          :   57   61   59   58   65  300
# Female_speech_and_woman_speaking        :   59   62   57   59   63  300
# Fill_(with_liquid)                      :   53   69   61   60   57  300
# Finger_snapping                         :   67   55   62   57   59  300
# Frying_(food)                           :   64   64   56   57   59  300
# Gasp                                    :   62   58   63   56   61  300
# Glockenspiel                            :   65   59   51   69   56  300
# Gong                                    :   59   57   62   61   61  300
# Gurgling                                :   60   58   61   65   56  300
# Harmonica                               :   60   59   58   60   63  300
# Hi-hat                                  :   55   54   64   66   61  300
# Hiss                                    :   61   61   62   62   54  300
# Keys_jangling                           :   63   55   60   63   59  300
# Knock                                   :   60   59   64   53   64  300
# Male_singing                            :   65   56   58   62   59  300
# Male_speech_and_man_speaking            :   58   64   56   58   64  300
# Marimba_and_xylophone                   :   63   58   53   68   58  300
# Mechanical_fan                          :   56   60   63   62   59  300
# Meow                                    :   61   58   64   62   55  300
# Microwave_oven                          :   59   58   56   61   66  300
# Motorcycle                              :   61   61   61   59   58  300
# Printer                                 :   61   60   60   60   59  300
# Purr                                    :   65   63   58   59   55  300
# Race_car_and_auto_racing                :   65   64   58   57   56  300
# Raindrop                                :   63   59   58   59   61  300
# Run                                     :   57   61   60   61   61  300
# Scissors                                :   73   60   48   57   62  300
# Screaming                               :   62   59   55   66   58  300
# Shatter                                 :   68   59   60   59   54  300
# Sigh                                    :   60   56   59   62   63  300
# Sink_(filling_or_washing)               :   65   64   51   65   55  300
# Skateboard                              :   64   60   59   59   58  300
# Slam                                    :   60   60   62   54   64  300
# Sneeze                                  :   61   58   62   64   55  300
# Squeak                                  :   57   64   58   61   60  300
# Stream                                  :   63   62   58   57   60  300
# Strum                                   :   59   57   51   62   71  300
# Tap                                     :   60   58   60   58   64  300
# Tick-tock                               :   60   61   63   60   56  300
# Toilet_flush                            :   59   66   59   58   58  300
# Traffic_noise_and_roadway_noise         :   56   60   62   62   60  300
# Trickle_and_dribble                     :   63   62   60   59   56  300
# Walk_and_footsteps                      :   58   63   62   59   58  300
# Water_tap_and_faucet                    :   67   64   57   63   49  300
# Waves_and_surf                          :   61   59   60   60   60  300
# Whispering                              :   57   58   60   67   58  300
# Writing                                 :   64   63   58   58   57  300
# Yell                                    :   63   60   62   57   58  300
# Zipper_(clothing)                       :   62   65   58   57   58  300
# total                                   : 4023 3973 3927 3961 3931 19815

# %%
# save
train_kind = "curated" if is_curated else "noisy"
train_opt_df.to_csv(ROOT_PATH / "data" / "fold" / "train_{}_sfk.csv".format(train_kind), index=None)
